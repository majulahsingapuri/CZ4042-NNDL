# %%
# Setting the seed here is sufficient. 
# If you don't plan to use these starter code, make sure you add this cell.

SEED = 42

import os
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

import random 
random.seed(SEED)

import numpy as np
np.random.seed(SEED)

import tensorflow as tf
tf.random.set_seed(SEED)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import IntegerLookup, Normalization, StringLookup
from tensorflow.keras.metrics import Accuracy
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('/tf/School/Neural Networks and Deep Learning/NNDL-Assignments/hdb_price_prediction.csv')
df
# Out:
#         month  year              full_address   nearest_stn  \
# 0           1  2017  406 ANG MO KIO AVENUE 10    Ang Mo Kio
# 1           1  2017   108 ANG MO KIO AVENUE 4    Ang Mo Kio
# 2           1  2017   602 ANG MO KIO AVENUE 5  Yio Chu Kang
# 3           1  2017  465 ANG MO KIO AVENUE 10    Ang Mo Kio
# 4           1  2017   601 ANG MO KIO AVENUE 5  Yio Chu Kang
# ...       ...   ...                       ...           ...
# 104089      8  2021       710 YISHUN AVENUE 5        Yishun
# 104090      8  2021      117 YISHUN RING ROAD        Yishun
# 104091      8  2021      453 YISHUN STREET 41        Khatib
# 104092      8  2021     505D YISHUN STREET 51        Khatib
# 104093      8  2021      161 YISHUN STREET 11        Yishun
#
#         dist_to_nearest_stn  dist_to_dhoby  degree_centrality  \
# 0                  1.007264       7.006044           0.016807
# 1                  1.271389       7.983837           0.016807
# 2                  1.069743       9.090700           0.016807
# 3                  0.946890       7.519889           0.016807
# 4                  1.092551       9.130489           0.016807
# ...                     ...            ...                ...
# 104089             0.826153      14.410089           0.016807
# 104090             1.045337      15.215236           0.016807
# 104091             1.424543      13.350952           0.016807
# 104092             1.259536      13.232993           0.016807
# 104093             0.405275      14.841775           0.016807
#
#         eigenvector_centrality         flat_model_type  remaining_lease_years  \
# 0                     0.006243        2 ROOM, Improved              61.333333
# 1                     0.006243  3 ROOM, New Generation              60.583333
# 2                     0.002459  3 ROOM, New Generation              62.416667
# 3                     0.006243  3 ROOM, New Generation              62.083333
# 4                     0.002459  3 ROOM, New Generation              62.416667
# ...                        ...                     ...                    ...
# 104089                0.000382  4 ROOM, New Generation              61.750000
# 104090                0.000382         4 ROOM, Model A              60.916667
# 104091                0.000968         4 ROOM, Model A              91.083333
# 104092                0.000968         4 ROOM, Model A              93.666667
# 104093                0.000382        5 ROOM, Improved              62.916667
#
#         floor_area_sqm storey_range  resale_price
# 0                 44.0     10 TO 12      232000.0
# 1                 67.0     01 TO 03      250000.0
# 2                 67.0     01 TO 03      262000.0
# 3                 68.0     04 TO 06      265000.0
# 4                 67.0     01 TO 03      265000.0
# ...                ...          ...           ...
# 104089            93.0     07 TO 09      390000.0
# 104090           104.0     07 TO 09      380000.0
# 104091            93.0     04 TO 06      433000.0
# 104092            93.0     01 TO 03      460000.0
# 104093           126.0     10 TO 12      550000.0
#
# [104094 rows x 13 columns]

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("resale_price")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature


def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = StringLookup if is_string else IntegerLookup
    # Create a lookup layer which will turn strings into integer indices
    lookup = lookup_class(output_mode="binary") # NOTE: as mentioned in the question paper, this actually does one-hot encoding. You could replace 'binary' with 'one_hot' if you wish to.

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# # Question 1
# ### Splitting Data

# %%
df.drop(columns=['full_address', 'nearest_stn'], inplace=True)
df.head()
# Out:
#    month  year  dist_to_nearest_stn  dist_to_dhoby  degree_centrality  \
# 0      1  2017             1.007264       7.006044           0.016807
# 1      1  2017             1.271389       7.983837           0.016807
# 2      1  2017             1.069743       9.090700           0.016807
# 3      1  2017             0.946890       7.519889           0.016807
# 4      1  2017             1.092551       9.130489           0.016807
#
#    eigenvector_centrality         flat_model_type  remaining_lease_years  \
# 0                0.006243        2 ROOM, Improved              61.333333
# 1                0.006243  3 ROOM, New Generation              60.583333
# 2                0.002459  3 ROOM, New Generation              62.416667
# 3                0.006243  3 ROOM, New Generation              62.083333
# 4                0.002459  3 ROOM, New Generation              62.416667
#
#    floor_area_sqm storey_range  resale_price
# 0            44.0     10 TO 12      232000.0
# 1            67.0     01 TO 03      250000.0
# 2            67.0     01 TO 03      262000.0
# 3            68.0     04 TO 06      265000.0
# 4            67.0     01 TO 03      265000.0

# %%
#Split data
train_dataframe = df.loc[df['year'] <= 2020]
val_dataframe = df.loc[df['year'] == 2021]

train_dataframe = train_dataframe.drop(columns='year')
val_dataframe = val_dataframe.drop(columns='year')

train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

train_ds = train_ds.batch(128)
val_ds = val_ds.batch(128)

# %% [markdown]
# We split the data by year as we want to use the historical data to predict the future data and not have it be affected by the future data.
#
# ### Building model

# %%
# Categorical features encoded as integers
month = keras.Input(shape=(1,), name="month", dtype="int64")

# Categorical feature encoded as string
flat_model_type = keras.Input(shape=(1,), name="flat_model_type", dtype="string")
storey_range = keras.Input(shape=(1,), name="storey_range", dtype="string")

# Numerical features
dist_to_nearest_stn = keras.Input(shape=(1,), name="dist_to_nearest_stn")
dist_to_dhoby = keras.Input(shape=(1,), name="dist_to_dhoby")
degree_centrality = keras.Input(shape=(1,), name="degree_centrality")
eigenvector_centrality = keras.Input(shape=(1,), name="eigenvector_centrality")
remaining_lease_years = keras.Input(shape=(1,), name="remaining_lease_years")
floor_area_sqm = keras.Input(shape=(1,), name="floor_area_sqm")

all_inputs = [
    month,
    flat_model_type,
    storey_range,
    dist_to_nearest_stn,
    dist_to_dhoby,
    degree_centrality,
    eigenvector_centrality,
    remaining_lease_years,
    floor_area_sqm,
]

# Integer categorical features
month_encoded = encode_categorical_feature(month, "month", train_ds, False)

# String categorical features
flat_model_type_encoded = encode_categorical_feature(flat_model_type, "flat_model_type", train_ds, True)
storey_range_encoded = encode_categorical_feature(storey_range, "storey_range", train_ds, True)

# Numerical features
dist_to_nearest_stn_encoded = encode_numerical_feature(dist_to_nearest_stn, "dist_to_nearest_stn", train_ds)
dist_to_dhoby_encoded = encode_numerical_feature(dist_to_dhoby, "dist_to_dhoby", train_ds)
degree_centrality_encoded = encode_numerical_feature(degree_centrality, "degree_centrality", train_ds)
eigenvector_centrality_encoded = encode_numerical_feature(eigenvector_centrality, "eigenvector_centrality", train_ds)
remaining_lease_years_encoded = encode_numerical_feature(remaining_lease_years, "remaining_lease_years", train_ds)
floor_area_sqm_encoded = encode_numerical_feature(floor_area_sqm, "floor_area_sqm", train_ds)

all_features = layers.concatenate(
    [
        month_encoded,
        flat_model_type_encoded,
        storey_range_encoded,
        dist_to_nearest_stn_encoded,
        dist_to_dhoby_encoded,
        degree_centrality_encoded,
        eigenvector_centrality_encoded,
        remaining_lease_years_encoded,
        floor_area_sqm_encoded,
    ]
)

# %% [markdown]
# #### Custom $R^{2}$ function

# %%
import tensorflow.keras.backend as K

def r2_score(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
x = layers.Dense(10, activation="relu")(all_features)
output = layers.Dense(1, activation="linear")(x)
model = keras.Model(all_inputs, output)
model.compile(tf.keras.optimizers.Adam(0.05), "mse", metrics=[Accuracy(), r2_score])

# %% [markdown]
# #### Visualising model

# %%
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### Model Checkpointing

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    mode='min')

# %% [markdown]
# ### Training model

# %%
history = model.fit(
    train_ds,
    batch_size=128,
    epochs=100,
    callbacks=[model_checkpoint_callback],
    verbose=1,
    validation_data=val_ds,
    )
# Out:
# Epoch 1/100
# 683/683 [==============================] - 2s 1ms/step - loss: 189632856064.0000 - accuracy: 0.0000e+00 - r2_score: -7.1555 - val_loss: 175632465920.0000 - val_accuracy: 0.0000e+00 - val_r2_score: -5.8907
# Epoch 2/100
# 683/683 [==============================] - 1s 1ms/step - loss: 69289803776.0000 - accuracy: 0.0000e+00 - r2_score: -1.9701 - val_loss: 40588152832.0000 - val_accuracy: 0.0000e+00 - val_r2_score: -0.5804
# Epoch 3/100
# 683/683 [==============================] - 1s 1ms/step - loss: 10976583680.0000 - accuracy: 0.0000e+00 - r2_score: 0.5348 - val_loss: 11043729408.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.5734
# Epoch 4/100
# 683/683 [==============================] - 1s 1ms/step - loss: 5546234368.0000 - accuracy: 0.0000e+00 - r2_score: 0.7641 - val_loss: 8589943808.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6683
# Epoch 5/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4997148160.0000 - accuracy: 0.0000e+00 - r2_score: 0.7868 - val_loss: 7986379264.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6909
# Epoch 6/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4630483456.0000 - accuracy: 0.0000e+00 - r2_score: 0.8023 - val_loss: 7683660288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7036
# Epoch 7/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4365612544.0000 - accuracy: 0.0000e+00 - r2_score: 0.8139 - val_loss: 7284979200.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7173
# Epoch 8/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4175544576.0000 - accuracy: 0.0000e+00 - r2_score: 0.8214 - val_loss: 7109854720.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7248
# Epoch 9/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4041911808.0000 - accuracy: 0.0000e+00 - r2_score: 0.8269 - val_loss: 6925524480.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7316
# Epoch 10/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3947340032.0000 - accuracy: 0.0000e+00 - r2_score: 0.8311 - val_loss: 6620086272.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7428
# Epoch 11/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3880764672.0000 - accuracy: 0.0000e+00 - r2_score: 0.8336 - val_loss: 6680673792.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7396
# Epoch 12/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3833285120.0000 - accuracy: 0.0000e+00 - r2_score: 0.8357 - val_loss: 6554238976.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7449
# Epoch 13/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3796926464.0000 - accuracy: 0.0000e+00 - r2_score: 0.8373 - val_loss: 6630788096.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7426
# Epoch 14/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3769358848.0000 - accuracy: 0.0000e+00 - r2_score: 0.8383 - val_loss: 6541128704.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7465
# Epoch 15/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3746754816.0000 - accuracy: 0.0000e+00 - r2_score: 0.8394 - val_loss: 6316073984.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7542
# Epoch 16/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3727394304.0000 - accuracy: 0.0000e+00 - r2_score: 0.8402 - val_loss: 6146569728.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7599
# Epoch 17/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3712101120.0000 - accuracy: 0.0000e+00 - r2_score: 0.8411 - val_loss: 6437054976.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7488
# Epoch 18/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3698637056.0000 - accuracy: 0.0000e+00 - r2_score: 0.8412 - val_loss: 6354039808.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7529
# Epoch 19/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3686805248.0000 - accuracy: 0.0000e+00 - r2_score: 0.8420 - val_loss: 6268166144.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7564
# Epoch 20/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3677737216.0000 - accuracy: 0.0000e+00 - r2_score: 0.8421 - val_loss: 6249985536.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7567
# Epoch 21/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3670280960.0000 - accuracy: 0.0000e+00 - r2_score: 0.8424 - val_loss: 6287265280.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7556
# Epoch 22/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3663146496.0000 - accuracy: 0.0000e+00 - r2_score: 0.8424 - val_loss: 6088867328.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7625
# Epoch 23/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3656304640.0000 - accuracy: 0.0000e+00 - r2_score: 0.8430 - val_loss: 6212441600.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7581
# Epoch 24/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3651208192.0000 - accuracy: 0.0000e+00 - r2_score: 0.8432 - val_loss: 6016147456.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7660
# Epoch 25/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3646713344.0000 - accuracy: 0.0000e+00 - r2_score: 0.8432 - val_loss: 6246953472.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7568
# Epoch 26/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3642714880.0000 - accuracy: 0.0000e+00 - r2_score: 0.8436 - val_loss: 6158413312.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7593
# Epoch 27/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3638170112.0000 - accuracy: 0.0000e+00 - r2_score: 0.8437 - val_loss: 6252675584.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7556
# Epoch 28/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3634993408.0000 - accuracy: 0.0000e+00 - r2_score: 0.8439 - val_loss: 6079104000.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7625
# Epoch 29/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3631947520.0000 - accuracy: 0.0000e+00 - r2_score: 0.8436 - val_loss: 6251347456.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7563
# Epoch 30/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3627902976.0000 - accuracy: 0.0000e+00 - r2_score: 0.8445 - val_loss: 6211117568.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7587
# Epoch 31/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3622315520.0000 - accuracy: 0.0000e+00 - r2_score: 0.8444 - val_loss: 6288360448.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7557
# Epoch 32/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3612006400.0000 - accuracy: 0.0000e+00 - r2_score: 0.8450 - val_loss: 6094888448.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7636
# Epoch 33/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3589591808.0000 - accuracy: 0.0000e+00 - r2_score: 0.8458 - val_loss: 6103583744.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7618
# Epoch 34/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3549354752.0000 - accuracy: 0.0000e+00 - r2_score: 0.8476 - val_loss: 6023942144.0000 - val_accuracy: 5.9798e-05 - val_r2_score: 0.7649
# Epoch 35/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3477192960.0000 - accuracy: 0.0000e+00 - r2_score: 0.8506 - val_loss: 6068667392.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7637
# Epoch 36/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3375852032.0000 - accuracy: 0.0000e+00 - r2_score: 0.8545 - val_loss: 5816399872.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7720
# Epoch 37/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3262528000.0000 - accuracy: 0.0000e+00 - r2_score: 0.8597 - val_loss: 5530797056.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7848
# Epoch 38/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3148881408.0000 - accuracy: 0.0000e+00 - r2_score: 0.8648 - val_loss: 5576068608.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7822
# Epoch 39/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3048080640.0000 - accuracy: 0.0000e+00 - r2_score: 0.8685 - val_loss: 5474813440.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7852
# Epoch 40/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2969217792.0000 - accuracy: 0.0000e+00 - r2_score: 0.8722 - val_loss: 5322377216.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7922
# Epoch 41/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2912560640.0000 - accuracy: 0.0000e+00 - r2_score: 0.8747 - val_loss: 5465583616.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7856
# Epoch 42/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2872602112.0000 - accuracy: 0.0000e+00 - r2_score: 0.8765 - val_loss: 5446516224.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7868
# Epoch 43/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2844142592.0000 - accuracy: 0.0000e+00 - r2_score: 0.8777 - val_loss: 5392062464.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7890
# Epoch 44/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2823554304.0000 - accuracy: 0.0000e+00 - r2_score: 0.8785 - val_loss: 5321369088.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7920
# Epoch 45/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2806335744.0000 - accuracy: 0.0000e+00 - r2_score: 0.8792 - val_loss: 5243291648.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7951
# Epoch 46/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2789629440.0000 - accuracy: 0.0000e+00 - r2_score: 0.8800 - val_loss: 5305292288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7935
# Epoch 47/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2775931136.0000 - accuracy: 0.0000e+00 - r2_score: 0.8806 - val_loss: 5332438016.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7912
# Epoch 48/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2764194304.0000 - accuracy: 0.0000e+00 - r2_score: 0.8809 - val_loss: 5265996288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7933
# Epoch 49/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2752249088.0000 - accuracy: 0.0000e+00 - r2_score: 0.8816 - val_loss: 5219835392.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7964
# Epoch 50/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2742737408.0000 - accuracy: 0.0000e+00 - r2_score: 0.8820 - val_loss: 5201943552.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7953
# Epoch 51/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2735081984.0000 - accuracy: 0.0000e+00 - r2_score: 0.8822 - val_loss: 5216875520.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7962
# Epoch 52/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2727140864.0000 - accuracy: 1.1445e-05 - r2_score: 0.8824 - val_loss: 5036960768.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8038
# Epoch 53/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2720470784.0000 - accuracy: 0.0000e+00 - r2_score: 0.8829 - val_loss: 5283578368.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7933
# Epoch 54/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2714247936.0000 - accuracy: 0.0000e+00 - r2_score: 0.8831 - val_loss: 5292657152.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7925
# Epoch 55/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2708786688.0000 - accuracy: 0.0000e+00 - r2_score: 0.8830 - val_loss: 5000197120.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8044
# Epoch 56/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2703949824.0000 - accuracy: 0.0000e+00 - r2_score: 0.8836 - val_loss: 5122569216.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7996
# Epoch 57/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2700220416.0000 - accuracy: 0.0000e+00 - r2_score: 0.8838 - val_loss: 5183854080.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7968
# Epoch 58/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2695625216.0000 - accuracy: 0.0000e+00 - r2_score: 0.8839 - val_loss: 5177949184.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7972
# Epoch 59/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2692040960.0000 - accuracy: 0.0000e+00 - r2_score: 0.8842 - val_loss: 5090164224.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8012
# Epoch 60/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2688082944.0000 - accuracy: 0.0000e+00 - r2_score: 0.8843 - val_loss: 5263224832.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7950
# Epoch 61/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2685412096.0000 - accuracy: 0.0000e+00 - r2_score: 0.8844 - val_loss: 5119709696.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7996
# Epoch 62/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2681968896.0000 - accuracy: 0.0000e+00 - r2_score: 0.8843 - val_loss: 5294491648.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7933
# Epoch 63/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2678217728.0000 - accuracy: 0.0000e+00 - r2_score: 0.8845 - val_loss: 5140647936.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7982
# Epoch 64/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2676150272.0000 - accuracy: 0.0000e+00 - r2_score: 0.8845 - val_loss: 4962763776.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8063
# Epoch 65/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2672774912.0000 - accuracy: 0.0000e+00 - r2_score: 0.8848 - val_loss: 5177811456.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7979
# Epoch 66/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2670376960.0000 - accuracy: 0.0000e+00 - r2_score: 0.8849 - val_loss: 5090742784.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8020
# Epoch 67/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2667843584.0000 - accuracy: 0.0000e+00 - r2_score: 0.8851 - val_loss: 5092763648.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8007
# Epoch 68/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2665572096.0000 - accuracy: 0.0000e+00 - r2_score: 0.8850 - val_loss: 5060921344.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8018
# Epoch 69/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2663443968.0000 - accuracy: 0.0000e+00 - r2_score: 0.8852 - val_loss: 5111273984.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8000
# Epoch 70/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2660637184.0000 - accuracy: 0.0000e+00 - r2_score: 0.8857 - val_loss: 4872493056.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8087
# Epoch 71/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2658685440.0000 - accuracy: 0.0000e+00 - r2_score: 0.8856 - val_loss: 5130934784.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7996
# Epoch 72/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2656825856.0000 - accuracy: 0.0000e+00 - r2_score: 0.8855 - val_loss: 5234546688.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7968
# Epoch 73/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2654915072.0000 - accuracy: 0.0000e+00 - r2_score: 0.8852 - val_loss: 5182362112.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7971
# Epoch 74/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2653382400.0000 - accuracy: 0.0000e+00 - r2_score: 0.8855 - val_loss: 5071707136.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8020
# Epoch 75/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2651395584.0000 - accuracy: 0.0000e+00 - r2_score: 0.8863 - val_loss: 4988233216.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8048
# Epoch 76/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2649912320.0000 - accuracy: 0.0000e+00 - r2_score: 0.8859 - val_loss: 5194096640.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7966
# Epoch 77/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2648521984.0000 - accuracy: 0.0000e+00 - r2_score: 0.8858 - val_loss: 5275110912.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7935
# Epoch 78/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2647592704.0000 - accuracy: 0.0000e+00 - r2_score: 0.8858 - val_loss: 4982308352.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8042
# Epoch 79/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2646538752.0000 - accuracy: 0.0000e+00 - r2_score: 0.8862 - val_loss: 5197367296.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7972
# Epoch 80/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2645232896.0000 - accuracy: 0.0000e+00 - r2_score: 0.8856 - val_loss: 5150697984.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7988
# Epoch 81/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2643582464.0000 - accuracy: 0.0000e+00 - r2_score: 0.8863 - val_loss: 5191761408.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7965
# Epoch 82/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2642652672.0000 - accuracy: 0.0000e+00 - r2_score: 0.8862 - val_loss: 5058817536.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8018
# Epoch 83/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2641345792.0000 - accuracy: 0.0000e+00 - r2_score: 0.8862 - val_loss: 5101772288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8006
# Epoch 84/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2640602624.0000 - accuracy: 0.0000e+00 - r2_score: 0.8863 - val_loss: 5085364736.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8011
# Epoch 85/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2639555072.0000 - accuracy: 0.0000e+00 - r2_score: 0.8860 - val_loss: 5200630272.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7973
# Epoch 86/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2638514176.0000 - accuracy: 0.0000e+00 - r2_score: 0.8861 - val_loss: 5041907200.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8026
# Epoch 87/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2637815040.0000 - accuracy: 0.0000e+00 - r2_score: 0.8863 - val_loss: 5048410624.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8027
# Epoch 88/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2637426944.0000 - accuracy: 0.0000e+00 - r2_score: 0.8860 - val_loss: 5069285888.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8014
# Epoch 89/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2637009152.0000 - accuracy: 1.1445e-05 - r2_score: 0.8863 - val_loss: 5189445120.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7972
# Epoch 90/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2635703040.0000 - accuracy: 0.0000e+00 - r2_score: 0.8864 - val_loss: 5033468928.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8028
# Epoch 91/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2634939136.0000 - accuracy: 0.0000e+00 - r2_score: 0.8864 - val_loss: 5133520384.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7987
# Epoch 92/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2634420480.0000 - accuracy: 0.0000e+00 - r2_score: 0.8867 - val_loss: 5165866496.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7969
# Epoch 93/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2633567488.0000 - accuracy: 0.0000e+00 - r2_score: 0.8866 - val_loss: 5062460928.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8022
# Epoch 94/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2633324800.0000 - accuracy: 0.0000e+00 - r2_score: 0.8867 - val_loss: 5013893632.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8037
# Epoch 95/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2632070912.0000 - accuracy: 0.0000e+00 - r2_score: 0.8866 - val_loss: 5107043840.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7993
# Epoch 96/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2631458304.0000 - accuracy: 0.0000e+00 - r2_score: 0.8865 - val_loss: 5135756288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7990
# Epoch 97/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2631131904.0000 - accuracy: 0.0000e+00 - r2_score: 0.8865 - val_loss: 5153711616.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7983
# Epoch 98/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2630564864.0000 - accuracy: 1.1445e-05 - r2_score: 0.8868 - val_loss: 5178884608.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7969
# Epoch 99/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2629580032.0000 - accuracy: 0.0000e+00 - r2_score: 0.8866 - val_loss: 4950045696.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8061
# Epoch 100/100
# 683/683 [==============================] - 1s 1ms/step - loss: 2629584640.0000 - accuracy: 1.1445e-05 - r2_score: 0.8869 - val_loss: 5129023488.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7997

# %%
plt.plot(np.sqrt(history.history['loss'][5:]))
plt.plot(np.sqrt(history.history['val_loss'][5:]))
plt.title('RMSE')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xticks(range(0, 95, 10), [i for i in range(5, 100, 10)])
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
lowest_error = np.argmin(history.history['val_loss'])
print(lowest_error)
print(history.history['val_r2_score'][lowest_error])
# Out:
# 69
# 0.8086559176445007

# %% [markdown]
# As seen above, the lowest test error occurs in epoch 69 with a $R^{2}$ value of 0.80
#
# ### Using best model to predict values

# %%
model.load_weights(checkpoint_filepath)
test = list(val_ds.as_numpy_iterator())[0]
predicted = model.predict(test[0])
actual = test[1]

plt.scatter(actual, predicted)
plt.title('scatter')
plt.ylabel('predicted')
plt.xlabel('actual')
plt.show()

# %% [markdown]
# # Question 2
#
# ### Adding Embedding layer

# %%
from math import floor

def encode_categorical_feature2(feature, name, dataset, is_string):
    lookup_class = StringLookup if is_string else IntegerLookup
    # Create a lookup layer which will turn strings into integer indices
    lookup = lookup_class(output_mode="int")

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = lookup(feature)
    num_categories = len(lookup.get_vocabulary())
    encoded_feature = tf.keras.layers.Embedding(num_categories, floor(num_categories/2))(encoded_feature)
    return encoded_feature

# %%
# Integer categorical features
month_encoded = encode_categorical_feature2(month, "month", train_ds, False)

# String categorical features
flat_model_type_encoded = encode_categorical_feature2(flat_model_type, "flat_model_type", train_ds, True)
storey_range_encoded = encode_categorical_feature2(storey_range, "storey_range", train_ds, True)

# Reshaping data
month_encoded = tf.keras.layers.Reshape((month_encoded.shape[1] * month_encoded.shape[2],))(month_encoded)
flat_model_type_encoded = tf.keras.layers.Reshape((flat_model_type_encoded.shape[1] * flat_model_type_encoded.shape[2],))(flat_model_type_encoded)
storey_range_encoded = tf.keras.layers.Reshape((storey_range_encoded.shape[1] * storey_range_encoded.shape[2],))(storey_range_encoded)

all_features = layers.concatenate(
    [
        month_encoded,
        flat_model_type_encoded,
        storey_range_encoded,
        dist_to_nearest_stn_encoded,
        dist_to_dhoby_encoded,
        degree_centrality_encoded,
        eigenvector_centrality_encoded,
        remaining_lease_years_encoded,
        floor_area_sqm_encoded,
    ],
)

# %%
x = layers.Dense(10, activation="relu")(all_features)
output = layers.Dense(1, activation="linear")(x)
model2 = keras.Model(all_inputs, output)
model2.compile(tf.keras.optimizers.Adam(0.05), "mse", metrics=[Accuracy(), r2_score])

# %%
keras.utils.plot_model(model2, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### Early stopping callback

# %%
early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model2.fit(
    train_ds,
    batch_size=128,
    epochs=100,
    callbacks=[model_checkpoint_callback, early_stop_callback],
    verbose=1,
    validation_data=val_ds,
    )
# Out:
# Epoch 1/100
# 683/683 [==============================] - 2s 1ms/step - loss: 45698519040.0000 - accuracy: 0.0000e+00 - r2_score: -0.9880 - val_loss: 11971067904.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.5386
# Epoch 2/100
# 683/683 [==============================] - 1s 1ms/step - loss: 8064392192.0000 - accuracy: 0.0000e+00 - r2_score: 0.6555 - val_loss: 10196781056.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6042
# Epoch 3/100
# 683/683 [==============================] - 1s 1ms/step - loss: 7041561088.0000 - accuracy: 0.0000e+00 - r2_score: 0.6978 - val_loss: 9261534208.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6400
# Epoch 4/100
# 683/683 [==============================] - 1s 1ms/step - loss: 6283067392.0000 - accuracy: 0.0000e+00 - r2_score: 0.7313 - val_loss: 8203720704.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6828
# Epoch 5/100
# 683/683 [==============================] - 1s 1ms/step - loss: 5614465024.0000 - accuracy: 0.0000e+00 - r2_score: 0.7593 - val_loss: 7777119744.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6983
# Epoch 6/100
# 683/683 [==============================] - 1s 1ms/step - loss: 5104471040.0000 - accuracy: 0.0000e+00 - r2_score: 0.7811 - val_loss: 7216013312.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7199
# Epoch 7/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4733414912.0000 - accuracy: 0.0000e+00 - r2_score: 0.7973 - val_loss: 6881352704.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7326
# Epoch 8/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4451993088.0000 - accuracy: 0.0000e+00 - r2_score: 0.8087 - val_loss: 6894024704.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7313
# Epoch 9/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4244445440.0000 - accuracy: 0.0000e+00 - r2_score: 0.8180 - val_loss: 6612480000.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7419
# Epoch 10/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4091400960.0000 - accuracy: 0.0000e+00 - r2_score: 0.8238 - val_loss: 7120090112.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7223
# Epoch 11/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3979099136.0000 - accuracy: 0.0000e+00 - r2_score: 0.8289 - val_loss: 6591398912.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7437
# Epoch 12/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3903096832.0000 - accuracy: 0.0000e+00 - r2_score: 0.8327 - val_loss: 6357686272.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7533
# Epoch 13/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3845237504.0000 - accuracy: 0.0000e+00 - r2_score: 0.8349 - val_loss: 6761440256.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7346
# Epoch 14/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3804902400.0000 - accuracy: 0.0000e+00 - r2_score: 0.8366 - val_loss: 5895490048.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7699
# Epoch 15/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3776164096.0000 - accuracy: 0.0000e+00 - r2_score: 0.8380 - val_loss: 6062642688.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7638
# Epoch 16/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3757872384.0000 - accuracy: 0.0000e+00 - r2_score: 0.8386 - val_loss: 5321547264.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7933
# Epoch 17/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3746228992.0000 - accuracy: 0.0000e+00 - r2_score: 0.8393 - val_loss: 6393105408.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7516
# Epoch 18/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3735485696.0000 - accuracy: 0.0000e+00 - r2_score: 0.8396 - val_loss: 5913095168.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7695
# Epoch 19/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3722078720.0000 - accuracy: 0.0000e+00 - r2_score: 0.8402 - val_loss: 5625175552.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7815
# Epoch 20/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3713770240.0000 - accuracy: 0.0000e+00 - r2_score: 0.8402 - val_loss: 5995424256.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7663
# Epoch 21/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3705825024.0000 - accuracy: 0.0000e+00 - r2_score: 0.8407 - val_loss: 5845127680.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7722
# Epoch 22/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3693598208.0000 - accuracy: 0.0000e+00 - r2_score: 0.8412 - val_loss: 5723233280.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7766
# Epoch 23/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3689270016.0000 - accuracy: 0.0000e+00 - r2_score: 0.8414 - val_loss: 6296605184.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7544
# Epoch 24/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3682388736.0000 - accuracy: 0.0000e+00 - r2_score: 0.8422 - val_loss: 5960795136.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7675
# Epoch 25/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3673251072.0000 - accuracy: 0.0000e+00 - r2_score: 0.8426 - val_loss: 5913821696.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7689
# Epoch 26/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3674327296.0000 - accuracy: 0.0000e+00 - r2_score: 0.8418 - val_loss: 6339194368.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7535

# %%
plt.plot(np.sqrt(history.history['loss'][5:]))
plt.plot(np.sqrt(history.history['val_loss'][5:]))
plt.title('RMSE')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xticks(range(0, 95, 10), [i for i in range(5, 100, 10)])
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
lowest_error = np.argmin(history.history['val_loss'])
print(lowest_error)
print(history.history['val_r2_score'][lowest_error])
# Out:
# 15
# 0.7933107614517212

# %%
model2.load_weights(checkpoint_filepath)
test = list(val_ds.as_numpy_iterator())[0]
predicted = model2.predict(test[0])
actual = test[1]

plt.scatter(actual, predicted)
plt.title('scatter')
plt.ylabel('predicted')
plt.xlabel('actual')
plt.show()

# %% [markdown]
# As we can see from the above, the model did reach its peak performance at an earlier epoch and the $R^2$ value is higher as well.
#
# # Question 3

# %%
removed_feature = []
rmse = []
r2 = []

# %%
tf.keras.backend.clear_session()

# Integer categorical features
month_encoded = encode_categorical_feature2(month, "month", train_ds, False)

# String categorical features
flat_model_type_encoded = encode_categorical_feature2(flat_model_type, "flat_model_type", train_ds, True)
storey_range_encoded = encode_categorical_feature2(storey_range, "storey_range", train_ds, True)

# Numerical features
dist_to_nearest_stn_encoded = encode_numerical_feature(dist_to_nearest_stn, "dist_to_nearest_stn", train_ds)
dist_to_dhoby_encoded = encode_numerical_feature(dist_to_dhoby, "dist_to_dhoby", train_ds)
degree_centrality_encoded = encode_numerical_feature(degree_centrality, "degree_centrality", train_ds)
eigenvector_centrality_encoded = encode_numerical_feature(eigenvector_centrality, "eigenvector_centrality", train_ds)
remaining_lease_years_encoded = encode_numerical_feature(remaining_lease_years, "remaining_lease_years", train_ds)
floor_area_sqm_encoded = encode_numerical_feature(floor_area_sqm, "floor_area_sqm", train_ds)

month_encoded = tf.keras.layers.Reshape((month_encoded.shape[1] * month_encoded.shape[2],))(month_encoded)
flat_model_type_encoded = tf.keras.layers.Reshape((flat_model_type_encoded.shape[1] * flat_model_type_encoded.shape[2],))(flat_model_type_encoded)
storey_range_encoded = tf.keras.layers.Reshape((storey_range_encoded.shape[1] * storey_range_encoded.shape[2],))(storey_range_encoded)

# %%
encoded = [
        month_encoded,
        flat_model_type_encoded,
        storey_range_encoded,
        dist_to_nearest_stn_encoded,
        dist_to_dhoby_encoded,
        #degree_centrality_encoded, removed in round 1
        #eigenvector_centrality_encoded, removed in round 2
        remaining_lease_years_encoded,
        #floor_area_sqm_encoded,
    ]

all_features = layers.concatenate(encoded)

# %%
x = layers.Dense(10, activation="relu")(all_features)
output = layers.Dense(1, activation="linear")(x)
model3 = keras.Model(all_inputs, output)
model3.compile(tf.keras.optimizers.Adam(0.05), "mse", metrics=[Accuracy(), r2_score])

history = model3.fit(
    train_ds,
    batch_size=128,
    epochs=100,
    callbacks=[model_checkpoint_callback, early_stop_callback],
    verbose=1,
    validation_data=val_ds,
)

removed_feature.append('Round 3: floor_area_sqm')
lowest_error = np.argmin(history.history['val_loss'])
r2.append(history.history['val_r2_score'][lowest_error])
rmse.append(history.history['val_loss'][lowest_error])

tf.keras.backend.clear_session()
# Out:
# Epoch 1/100
# 683/683 [==============================] - 2s 2ms/step - loss: 28921485312.0000 - accuracy: 0.0000e+00 - r2_score: -0.2207 - val_loss: 13126731776.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.4956
# Epoch 2/100
# 683/683 [==============================] - 1s 2ms/step - loss: 9524311040.0000 - accuracy: 0.0000e+00 - r2_score: 0.5943 - val_loss: 11200500736.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.5669
# Epoch 3/100
# 683/683 [==============================] - 1s 1ms/step - loss: 8593720320.0000 - accuracy: 0.0000e+00 - r2_score: 0.6321 - val_loss: 10234857472.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6031
# Epoch 4/100
# 683/683 [==============================] - 1s 1ms/step - loss: 8156665856.0000 - accuracy: 0.0000e+00 - r2_score: 0.6508 - val_loss: 10404080640.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.5966
# Epoch 5/100
# 683/683 [==============================] - 1s 1ms/step - loss: 7823307776.0000 - accuracy: 0.0000e+00 - r2_score: 0.6652 - val_loss: 11318995968.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.5615
# Epoch 6/100
# 683/683 [==============================] - 1s 1ms/step - loss: 7426354688.0000 - accuracy: 0.0000e+00 - r2_score: 0.6819 - val_loss: 9679326208.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6237
# Epoch 7/100
# 683/683 [==============================] - 1s 1ms/step - loss: 6960284672.0000 - accuracy: 0.0000e+00 - r2_score: 0.7022 - val_loss: 8656245760.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6640
# Epoch 8/100
# 683/683 [==============================] - 1s 1ms/step - loss: 6382445568.0000 - accuracy: 0.0000e+00 - r2_score: 0.7271 - val_loss: 7915948544.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6939
# Epoch 9/100
# 683/683 [==============================] - 1s 1ms/step - loss: 5805508096.0000 - accuracy: 0.0000e+00 - r2_score: 0.7517 - val_loss: 7024396288.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7259
# Epoch 10/100
# 683/683 [==============================] - 1s 1ms/step - loss: 5260339712.0000 - accuracy: 0.0000e+00 - r2_score: 0.7750 - val_loss: 6923793408.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7306
# Epoch 11/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4830771200.0000 - accuracy: 0.0000e+00 - r2_score: 0.7935 - val_loss: 7824096256.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.6956
# Epoch 12/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4357327360.0000 - accuracy: 0.0000e+00 - r2_score: 0.8128 - val_loss: 6735520768.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7371
# Epoch 13/100
# 683/683 [==============================] - 1s 1ms/step - loss: 4055059200.0000 - accuracy: 0.0000e+00 - r2_score: 0.8263 - val_loss: 6017115648.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7662
# Epoch 14/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3793698048.0000 - accuracy: 0.0000e+00 - r2_score: 0.8370 - val_loss: 5894036480.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7706
# Epoch 15/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3611201280.0000 - accuracy: 0.0000e+00 - r2_score: 0.8447 - val_loss: 5019670528.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.8047
# Epoch 16/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3535489536.0000 - accuracy: 0.0000e+00 - r2_score: 0.8480 - val_loss: 5444674048.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7876
# Epoch 17/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3488352768.0000 - accuracy: 0.0000e+00 - r2_score: 0.8498 - val_loss: 6146106880.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7601
# Epoch 18/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3442450688.0000 - accuracy: 0.0000e+00 - r2_score: 0.8517 - val_loss: 5460805120.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7868
# Epoch 19/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3411408640.0000 - accuracy: 0.0000e+00 - r2_score: 0.8531 - val_loss: 5863567360.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7722
# Epoch 20/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3397804544.0000 - accuracy: 0.0000e+00 - r2_score: 0.8537 - val_loss: 5443504640.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7884
# Epoch 21/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3386092800.0000 - accuracy: 0.0000e+00 - r2_score: 0.8544 - val_loss: 6559426048.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7441
# Epoch 22/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3383570688.0000 - accuracy: 1.1445e-05 - r2_score: 0.8543 - val_loss: 7044813312.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7242
# Epoch 23/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3381208064.0000 - accuracy: 0.0000e+00 - r2_score: 0.8545 - val_loss: 6188304384.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7588
# Epoch 24/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3379020544.0000 - accuracy: 0.0000e+00 - r2_score: 0.8549 - val_loss: 6003445760.0000 - val_accuracy: 5.9798e-05 - val_r2_score: 0.7649
# Epoch 25/100
# 683/683 [==============================] - 1s 1ms/step - loss: 3367031296.0000 - accuracy: 0.0000e+00 - r2_score: 0.8550 - val_loss: 5894316032.0000 - val_accuracy: 0.0000e+00 - val_r2_score: 0.7701

# %%
results = pd.DataFrame(data={
    'Feature': removed_feature,
    'r2': r2,
    'RMSE': rmse
})

results.head()
# Out:
#                Feature        r2          RMSE
# 0              control  0.823838  4.488620e+09
# 1                month  0.841078  4.068735e+09
# 2      flat_model_type  0.791326  5.365562e+09
# 3         storey_range  0.810840  4.823834e+09
# 4  dist_to_nearest_stn  0.786532  5.470250e+09

# %%
plt.figure(figsize=(12, 6), dpi=72)
plt.plot(results.RMSE)
plt.axhline(y=results.RMSE[0], color='r', linestyle='-')
plt.title('Model Comparison')
plt.ylabel('error')
plt.xlabel('feature')
plt.xticks(range(len(results.Feature)), results.Feature, rotation='vertical')
plt.legend(['RMSE'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=72)
plt.plot(results.r2)
plt.axhline(y=results.r2[0], color='r', linestyle='-')
plt.title('Model Comparison')
plt.ylabel('r^2')
plt.xlabel('feature')
plt.xticks(range(len(results.Feature)), results.Feature, rotation='vertical')
plt.legend(['r2'], loc='upper left')
plt.show()

# %% [markdown]
# As we can see above, after going through the RFE process, we have eliminated `degree_centrality` and `eigenvector_centrality` as the two variables that upon removing, the model has an increase in performance. It seems that being in a central location does not have that much of an importance to the price of HDB houses and that seems about right given that towns in Singapore are designed to be self-contained with their own slew of ammenities and entertainment areas. Hence there is no real need to travel outside of the town, causing the factor to not be that important for the model.
#
# # Conclusion
#
# We have seen from the experiments above that we can indeed predict a numerical value from a mix of numeric and categorical data after making the appropriate adjustments to the inputs and feeding it into the model. We have also seen how we can introduce custom metrics during the evaluation with the $R^2$ score and introduce stopping and saving callbacks to ensure that we extract the best model from the training phase. We have also gone through the RFE process to determine the optimal model for our use case. To determine which are the factors that lead to a price increase, we can look at the weights of the dense network to see which inputs the model has prioritised.
